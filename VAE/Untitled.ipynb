# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("models/simple_model", "rb") as f:
    my_model = torch.load(f)

# %%
sample = Variable(torch.randn(64, 20)).cuda()
sample = my_model.decode(sample).cpu()

# %%
from torchvision.utils import make_grid

# %%
plt.figure(figsize=(10, 10))


def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)), interpolation='nearest')

show(make_grid(sample.data.view(64, 1, 28, 28), ))

# %%
sample
# Out:
# Variable containing:
#  0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#  0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#  0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#           ...             ⋱             ...
#  0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#  0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
#  0.0000  0.0000  0.0000  ...   0.0000  0.0000  0.0000
# [torch.FloatTensor of size 64x784]
